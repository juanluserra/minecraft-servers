# %% [markdown]
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
# ```
# **Crea un Servidor de Minecraft en Google Colab! (Versión Modificada por SoyMichas y en Español)**
#
# ---
#
# El Script de abajo hará que tu servidor se inicie. Primero tendrás que crear el servidor para poder usarlo - no te preocupes, los scripts de abajo harán la gran mayoría del trabajo para ti. A lo mejor quieres cambiar la región del servidor, revisa abajo.
#
# Original: https://github.com/thecoder-001/MineColab

# %% [markdown]
# # **1º Paso -> Crear-el-servidor (Solo hacer la primera vez)**
#
# El codigo de abajo creará tu servidor y aceptará el EULA. Cuando uses estos scripts, Tu servidor estará listo para iniciarse.

# %% [markdown]
# **Descargar el Servidor de Minecraft**
#
# El codigo de abajo descargará Paper, un tipo de servidor Vanilla de alto rendimiento el cual permite utilizar plugins.
# Si quieres usar otro tipo de server.jar ponlo en la carpeta Drive manualmente.
#
# - Los archivos del servidor estarán guardados en tu Google Drive (Los de la cuenta de Google que elijas o estes usando)

# %%
# Nombramos la carpeta del servidor
folder_name = "apocalipsis-culo"

# %%
# Cambia "1.21" con la version que desees.
# Available tested versions / Versiones disponibles testeadas:
# - 1.21
# - 1.20
# - 1.19
# - 1.18
# - 1.17
# - 1.16
# - 1.15
# - 1.14
# - 1.13
# - 1.12
# - 1.11
# - 1.10
# - 1.9
# - 1.8
# Newer versions might work too, however this isn't guaranteed. / Las nuevas versiones deberían funcionar, pero no es garantizado.
version = '1.20.1'

#Chose server type. Currently available versions:
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)

server_type = 'forge'

# En caso de que uses FORGE (OBLIGATORIO):
forge_version = "47.4.0"

from google.colab import drive
import requests
import json

drive.mount('/content/drive')

! mkdir "/content/drive/My Drive/$folder_name"
# %cd "/content/drive/My Drive/$folder_name"

if server_type == 'paper':
  a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
  b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
  print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
  serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
  serverURL = f"https://maven.minecraftforge.net/net/minecraftforge/forge/{version}-{forge_version}/forge-{version}-{forge_version}-installer.jar"

if server_type == 'vanilla':
  serverURL = "https://mcutils.com/api/server-jars/vanilla/" + version + "/download"

if server_type == 'fabric':
  serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/1.0.1/fabric-installer-1.0.1.jar'

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar'}

print('Descargando a Google Drive...')

r = requests.get(serverURL)

if r.status_code == 200:
  with open(f'/content/drive/My Drive/{folder_name}/' + jar_name[server_type], 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona / Most likely you entered a unsupported version. Try running the code again if you think that shouldn\'t have happened.')

if server_type == 'fabric':
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
  # %cd "/content/drive/My Drive/$folder_name"
  # !java -jar forge.jar --installServer

colabconfig = {"server_type": server_type,
               "server_version": version}
json.dump(colabconfig, open("colabconfig.json",'w'))


from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/$folder_name"
# !echo "eula=true" >> eula.txt

# %% [markdown]
# # **-> Iniciar el servidor de Minecraft - Usar esto siempre que quieras abrirlo**
#
# **IMPORTANTE:**
# - Para poner un comando por consola, lo puedes hacer por aquí. Básicamente esto de abajo será tu consola (donde pondrás comandos y verás los logs)
# - Es recomendable tener la pestaña de Google Colab abierta para que el servidor no se cierre, es posible que cada cierto tiempo te pida que resuelvas un captcha.
#
#   **Si usas NGROK:**
#   - La IP cambiará siempre que reinicies el servidor.
#   - Tienes que poner el TOKEN de Ngrok abajo, entra en este link https://dashboard.ngrok.com/auth para obtener tu token (tienes que tener una cuenta creada en ngrok)
#   - Puedes cambiar en este codigo más abajo la REGIÓN, esto es importante para el LAG y PING. Usa las regiones más cercanas a ti. La región predeterminada es Estados Unidos, la cuál no es recomendada para paises de America del sur o España. Para estos se pueden usar regiones como 'sa' (Brasil) y 'eu' (Europa). Puedes cambiarlo en este código de abajo donde esta señalado.
#
#   **Si usas PLAYIT:**
#   - Tienes que darle click al link que aparecerá, ahí tendrás que crear un tunnel para Minecraft y usar la IP que te dará la aplicación.

# %%
from genericpath import exists
import os
import re
import json
import glob
import time
import threading

# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"

from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/$folder_name"
# !ls

# Dirección archivos de palyit
key_colab = "/root/.config/playit_gg/playit.toml"
key_drive = "/content/drive/My Drive/playit_gg/playit.toml"

# Creamos las carpetas de playit en colab y drive
os.makedirs("/root/.config/playit_gg", exist_ok=True)
os.makedirs("/content/drive/My Drive/playit_gg", exist_ok=True)
print("Directorios de playit creados")

# Función que se ejecutará en segundo plano para comprobar si existe
# un archivo en drive de playit_gg y copiarlo cuando se cree en colab
def monitor_and_copy():
    while not os.path.exists(key_drive):
        if os.path.exists(key_colab):
            ! cp "$key_colab" "$key_drive"
            break  # Sale del bucle después de copiar
        time.sleep(60)  # Verifica cada 60 segundos
    print("Archivo de playit_gg copiado a drive")

# Revisamos si existe un archivo de playit
# Si no hay un archivo de playit lo copiamos de drive
if not os.path.exists(key_colab) and os.path.exists(key_drive):
  # !cp "$key_drive" "$key_colab"
  print("Archivo de playit copiado desde drive")
elif not os.path.exists(key_drive):
  print("No existe un archivo de playit en drive")
  copy_thread = threading.Thread(target=monitor_and_copy)
  copy_thread.daemon = True  # El hilo se cerrará cuando el programa principal termine
  copy_thread.start()


if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"}
  json.dump(colabconfig, open("colabconfig.json",'w'))

version = colabconfig["server_version"]
if colabconfig["server_version"] < "1.17":
  # !sudo apt-get purge openjdk* > /dev/null 2>&1
  # !sudo apt-get install openjdk-8-jre-headless &>/dev/null && echo "Yay! Openjdk8 has been successfully installed." || echo "Failed to install OpenJdk8."
elif colabconfig["server_version"] >= "1.20.5":
  # !sudo apt-get purge openjdk* > /dev/null 2>&1
  # !sudo apt-get install openjdk-21-jre-headless &>/dev/null && echo "Yay! Openjdk21 has been successfully installed." || echo "Failed to install OpenJdk8."
else:
  # !sudo apt-get purge openjdk* > /dev/null 2>&1
  # !sudo apt-get install openjdk-17-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "17" :
  print("Se esta utilizando JAVA 17 - You are using JAVA 17.")
elif java_ver[0] == "21" :
  print("Se esta utilizando JAVA 21 - You are using JAVA 21.")
else:
  print("Estas utilizando una versión inferior a JAVA 17: ", java_ver[0], ". You are using a downgraded java version. Minecraft 1.17+ might not work.")

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': 'mohist.jar'}
jar_name = jar_list[colabconfig["server_type"]]

if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = ""
# memory_allocation = "-Xms8704M -Xmx8704M"
memory_allocation = "-Xms11264M -Xmx11264M"

# Chose the tunnle service you want to use
# Available options: ngrok, playit
tunnel_service = "playit" # Si prefieres usar NGROK cámbialo aquí <--------
print("Usando", tunnel_service)

if tunnel_service == "ngrok":
  # !pip -q install pyngrok
  from pyngrok import conf, ngrok

  # Ask for the ngrok authtoken
  print("Consigue tu authtoken de https://dashboard.ngrok.com/auth")
  import getpass

  # v - - - - - - - TOKEN  - - - - - - - v

  authtoken = ""  # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

  ! ngrok authtoken $authtoken # login to ngrok

  # Sets default ngrok region

  # v - - - - - - - REGIONES DISPONIBLES  - - - - - - - v

  # ap - Asia/Pacific (Singapore)
  # au - Australia (Sydney)
  # eu - Europa (Frankfurt - Alemania)
  # in - India (Mumbai)
  # jp - Japan (Tokyo)
  # sa - America del sur (São Paulo - Brasil)
  # us - United States (Ohio)
  conf.get_default().region = 'us'  # <--- Cambia esto por la region que quieras (solo ngrok)

  # ^ - - - - - - - REGIONES DISPONIBLES  - - - - - - - ^

  # Connect to ngrok
  url = ngrok.connect(25565, 'tcp')
  print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

elif tunnel_service == "playit":
  ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
  ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
  print('Iniciando servidor...')
  ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg instalado" || echo "Error al instalar playit"
  if colabconfig["server_type"] == "forge":
    version = colabconfig["server_version"]
    if colabconfig["server_version"] < "1.17":
      oldpathtoforge = glob.glob(f"/content/drive/My Drive/{folder_name}/forge-{version}-*.jar")
      if oldpathtoforge:  # Check if the list is not empty
        path = oldpathtoforge[0]  # Get the first path from the list
        print(path)
        ! playit & java $memory_allocation -jar "{path}" nogui
      else:
        print("No forge universal jar found.")
    else:
      pathtoforge = glob.glob(f"/content/drive/My Drive/{folder_name}/libraries/net/minecraftforge/forge/{version}-*/unix_*.txt")
      if pathtoforge:  # Check if the list is not empty
        path = pathtoforge[0]  # Get the first path from the list
        print(path)
        ! playit & java @user_jvm_args.txt "@{path}" "$@"
      else:
        print("No unix_args.txt found.")
  else:
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

if colabconfig["server_type"] == "forge":
  version = colabconfig["server_version"]
  if colabconfig["server_version"] < "1.17":
    oldpathtoforge = glob.glob(f"/content/drive/My Drive/{folder_name}/forge-{version}-*.jar")
    if oldpathtoforge:  # Check if the list is not empty
      path = oldpathtoforge[0]  # Get the first path from the list
      print(path)
      # !java $memory_allocation -jar "{path}" nogui
    else:
      print("No forge universal jar found.")
  else:
    pathtoforge = glob.glob(f"/content/drive/My Drive/{folder_name}/libraries/net/minecraftforge/forge/{version}-*/unix_*.txt")
    if pathtoforge:  # Check if the list is not empty
      path = pathtoforge[0]  # Get the first path from the list
      print(path)
      # !java @user_jvm_args.txt "@{path}" "$@"
    else:
      print("No unix_args.txt found.")
else:
 # !java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220512473 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220515696 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:41:56] [main/INFO] [ne.mi.fm.lo.ImmediateWindowHandler/]: ImmediateWindowProvider not loading because launch target is forgeserver
# [17:41:56] [main/INFO] [co.te.re.Redirector/]: Redirector CoreMod initialized successfully!
# [17:41:57] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/content/drive/My%20Drive/apocalipsis-culo/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2365!/ Service=ModLauncher Env=SERVER
# 8playit (v0.15.26): 1744220518854 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:00] [main/WARN] [ne.mi.fm.lo.mo.ModDiscoverer/SCAN]: Locator {mods folder locator at /content/drive/My Drive/apocalipsis-culo/mods} returned 1 files which are client-side-only mods, but we're on a dedicated server. They will be skipped!
# [17:42:01] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/drive/My Drive/apocalipsis-culo/libraries/net/minecraftforge/fmlcore/1.20.1-47.4.0/fmlcore-1.20.1-47.4.0.jar is missing mods.toml file
# 8playit (v0.15.26): 1744220522160 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:02] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/drive/My Drive/apocalipsis-culo/libraries/net/minecraftforge/javafmllanguage/1.20.1-47.4.0/javafmllanguage-1.20.1-47.4.0.jar is missing mods.toml file
# [17:42:02] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/drive/My Drive/apocalipsis-culo/libraries/net/minecraftforge/lowcodelanguage/1.20.1-47.4.0/lowcodelanguage-1.20.1-47.4.0.jar is missing mods.toml file
# [17:42:03] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /content/drive/My Drive/apocalipsis-culo/libraries/net/minecraftforge/mclanguage/1.20.1-47.4.0/mclanguage-1.20.1-47.4.0.jar is missing mods.toml file
# [17:42:04] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [17:42:04] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: kiwi. Using Mod File: /content/drive/My Drive/apocalipsis-culo/mods/Kiwi-1.20.1-Forge-11.8.29.jar
# [17:42:04] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 16 dependencies adding them to mods collection
# 8playit (v0.15.26): 1744220525430 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220528508 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220531603 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220535326 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220538586 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744220542198 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:22] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [17:42:24] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [ca.spottedleaf.starlight.mixin.MixinConnector]
# [17:42:24] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# 8playit (v0.15.26): 1744220545391 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:27] [main/INFO] [ModernFix/]: Loaded configuration file for ModernFix 5.20.2+mc1.20.1: 87 options available, 0 override(s) found
# [17:42:27] [main/INFO] [ModernFix/]: Applying Nashorn fix
# [17:42:27] [main/INFO] [ModernFix/]: Applied Forge config corruption patch
# [17:42:27] [main/INFO] [co.te.re.Redirector/]: Redirecting com/llamalad7/mixinextras/service/MixinExtrasVersion
# [17:42:28] [main/INFO] [Embeddium/]: Loaded configuration file for Embeddium: 225 options available, 0 override(s) found
# [17:42:28] [main/INFO] [co.te.re.Redirector/]: Redirecting org/embeddedt/embeddium_integrity/MixinTaintDetector$EnforceLevel
# [17:42:28] [main/WARN] [mixin/]: Reference map 'mysticaloaktree-common-refmap.json' for mysticaloaktree-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:28] [main/WARN] [mixin/]: Reference map 'mysticaloaktree-forge-refmap.json' for mysticaloaktree.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:28] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:28] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:28] [main/WARN] [mixin/]: Reference map 'trashslot.refmap.json' for trashslot.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:29] [main/WARN] [mixin/]: Reference map 'puzzlesaccessapi.common.refmap.json' for puzzlesaccessapi.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [17:42:29] [main/WARN] [mixin/]: Reference map 'ambientadditions.refmap.json' for ambientadditions.mixins.json could not be read. If this is a development environment you can ignore this message
# 8playit (v0.15.26): 1744220549562 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:29] [main/INFO] [co.te.re.Redirector/]: Redirecting malte0811/ferritecore/mixin/config/FerriteMixinConfig$LithiumSupportState
# [17:42:29] [main/INFO] [co.te.re.Redirector/]: Redirecting fuzs/puzzleslib/api/core/v1/ModLoader
# [17:42:29] [main/INFO] [Puzzles Lib/]: Loading 179 mods:
# 	- abyssal_decor 1.0.0
# 	- alexsdelight 1.5
# 	- alexsmobs 1.22.9
# 	- alltheleaks 0.1.2-beta+1.20.1-forge
# 		\-- mixinsquared 0.2.0
# 	- almanac 1.0.2
# 	- ambientadditions 1.20.1-1.1.0
# 	- amendments 1.20-1.2.19
# 	- appleskin 2.5.1+mc1.20.1
# 	- architectury 9.2.14
# 	- athena 3.1.2
# 	- attributefix 21.0.4
# 	- autumnity 5.0.2
# 	- balm 7.3.25
# 		\-- kuma_api 20.1.10
# 	- betteranimationscollection 8.0.0
# 	- betterdeserttemples 1.20-Forge-3.0.3
# 	- betterdungeons 1.20-Forge-4.0.4
# 	- betterendisland 1.20-Forge-2.0.6
# 	- betterfortresses 1.20-Forge-2.0.6
# 	- betterjungletemples 1.20-Forge-2.0.5
# 	- bettermineshafts 1.20-Forge-4.0.4
# 	- betteroceanmonuments 1.20-Forge-3.0.4
# 	- betterstrongholds 1.20-Forge-4.0.3
# 	- bettervillage 3.3.0
# 	- betterwitchhuts 1.20-Forge-3.0.3
# 	- blueprint 7.1.2
# 	- boatbreakfix 1.0.2
# 	- bocchium 1.20.1-0.0.3
# 	- bookshelf 20.2.13
# 	- brewery 1.1.9
# 	- carryon 2.1.2.7
# 	- cavesanddepths 1.2.7
# 	- charmofundying 6.5.0+1.20.1
# 		\-- spectrelib 0.13.15+1.20.1
# 	- chipped 3.0.7
# 	- citadel 2.6.1
# 	- cleanswing 1.8
# 	- collective 7.94
# 	- comforts 6.4.0+1.20.1
# 	- controlling 12.0.2
# 	- creativecore 2.12.32
# 	- crittersandcompanions 2.2.2
# 	- cupboard 1.20.1-2.7
# 	- curios 5.12.1+1.20.1
# 	- curiouslanterns 1.20.1-1.3.6
# 	- decoration_delight 1.0.0
# 	- decorative_blocks 4.1.3
# 	- decorative_winter 3.0.0
# 	- despawn_tweaker 1.20.1-1.0.0
# 	- doapi 1.2.15
# 		\-- terraform 7.0.1
# 	- doespotatotick 1.20.1-4.0.2
# 	- doubledoors 6.2
# 	- duckling 3.0.0
# 	- dungeoncrawl 2.3.15
# 	- dungeons_arise 2.1.58-1.20.x
# 	- dungeons_arise_seven_seas 1.0.2
# 	- dustrial_decor 1.3.2
# 	- dustydecorations 1.3
# 	- easyanvils 8.0.2
# 	- easymagic 8.0.1
# 	- ecologics 2.2.0
# 	- embeddium 0.3.31+mc1.20.1
# 		\-- rubidium 0.7.1
# 	- enchdesc 17.1.19
# 	- endersdelight 1.0.3
# 	- farm_and_charm 1.0.4
# 	- farmers_structures 1.0.0
# 	- farmersdelight 1.20.1-1.2.7
# 	- fastasyncworldsave 1.20.1-2.4
# 	- fastbench 8.0.4
# 	- fastfurnace 8.0.2
# 	- ferritecore 6.0.1
# 	- forge 47.4.0
# 	- framework 0.7.12
# 	- fusion 1.2.5
# 	- geckolib 4.7.1.2
# 	- geophilic 3.4
# 	- geophilic_reforged 1.2.0
# 	- ghosts 1.1.0
# 	- globalxp 1.12
# 	- gravestone 1.20.1-1.0.24
# 	- incendium 5.3.5
# 	- inventorysorter 23.0.8
# 	- ironchest 1.20.1-14.4.4
# 	- jade 11.12.3+forge
# 	- jamlib 1.3.2+1.20.1-patch.1
# 	- jeed 1.20-2.2.5
# 	- jei 15.20.0.106
# 	- jeresources 1.4.0.247
# 	- journeymap 5.10.3
# 	- justenoughbreeding 1.5.0
# 	- justzoom 2.1.1
# 	- kiwi 11.8.29+forge
# 	- kleeslabs 15.0.6
# 	- konkrete 1.8.0
# 	- ksyxis 1.3.3
# 	- letmedespawn 1.5.0
# 	- libraryferret 4.0.0
# 	- lootintegrations 1.20.1-4.3
# 	- lootintegrations_yungs 1
# 	- lootr 0.7.35.91
# 	- magic_vibe_decorations 1.0.4
# 	- maxhealthfix 12.0.3
# 	- mca 7.6.3+1.20.1
# 	- meadow 1.3.24
# 	- medieval_deco 1.2
# 	- minecraft 1.20.1
# 	- moa_decor_bath 1.20.1
# 	- modernfix 5.20.2+mc1.20.1
# 	- monolib 2.0.0
# 	- moonlight 1.20-2.13.81
# 	- more_useful_copper 2.0.0
# 	- mr_dungeons_andtaverns 3.0.3.f
# 	- mr_tidal_towns 1.3.4
# 	- mysticaloaktree 1.20-1.11
# 	- naturalist 5.0pre2
# 		\-- midnightlib 1.4.2
# 	- nerb 0.4.1
# 	- nethersdelight 1.20.1-4.0
# 	- oceansdelight 1.0.2-1.20
# 	- octolib 0.5.0.1
# 	- onlylooking 1.20.1-4.1.1
# 	- opf 1
# 	- paraglider 20.1.3
# 	- pizzadelight 1.0.0
# 	- placebo 8.6.3
# 	- portablecraftingtable 3.2.2-[FORGE]
# 	- puzzleslib 8.1.32
# 		|-- mixinextras 0.4.1
# 		\-- puzzlesaccessapi 20.1.1
# 	- radiantgear 2.2.0+1.20.1
# 	- rechiseled 1.1.6
# 	- rechiseled_chipped 1.2
# 	- resourcefullib 2.1.29
# 	- ribbits 1.20.1-Forge-3.0.4
# 	- rightclickharvest 4.5.3+1.20.1
# 	- rpg_companions_tiny_dragons 0.0.5
# 	- rusticdelight 1.4.1
# 	- sawmill 1.20-1.4.6
# 	- searchables 1.0.3
# 	- silentlib 8.0.0
# 	- skd 0.3.1
# 	- smoothchunk 1.20.1-4.1
# 	- snowrealmagic 10.5.2
# 		|-- fabric_api_base 0.4.31+ef105b4977
# 		|-- fabric_renderer_api_v1 3.2.1+1d29b44577
# 		\-- fabric_renderer_indigo 1.5.2+b5b2da4177
# 	- sodiumdynamiclights 1.0.9
# 	- sodiumoptionsapi 1.0.10
# 	- some_assembly_required 1.20.1-4.1.1
# 	- sophisticatedbackpacks 3.23.6.1211
# 	- sophisticatedcore 1.2.23.902
# 	- spawn 1.20.1-1.0.2
# 	- spelunkers_charm 3.6.0
# 	- starlight 1.1.2+forge.1cda73c
# 	- structureessentials 1.20.1-4.6
# 	- supermartijn642configlib 1.1.8
# 	- supermartijn642corelib 1.1.18
# 	- supplementaries 1.20-3.1.24
# 	- suppsquared 1.20-1.1.21
# 	- tameablebeasts 6.2
# 	- terrablender 3.0.1.10
# 	- terralith 2.5.4
# 	- totw_modded 1.0.6
# 	- trashslot 15.1.2
# 	- treechop 0.19.0
# 	- universalbonemeal 8.0.1
# 	- unusualfishmod 1.1.8
# 	- vinery 1.4.39
# 	- visuality 2.0.2
# 	- wardrobe 1.0.3.1
# 	- waystones 14.1.11
# 	- williams_hedgehogs 1.0.0
# 	- wwoo_forge 2.0.0
# 	- xkdeco 0.8.5+forge
# 	- yungsapi 1.20-Forge-4.0.6
# 	- yungsbridges 1.20-Forge-4.0.3
# 	- yungscavebiomes 1.20.1-Forge-2.0.4
# 	- yungsextras 1.20-Forge-4.0.3
# [17:42:31] [main/INFO] [co.cu.Cupboard/]: Loaded config for: structureessentials.json
# [17:42:31] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:31] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:32] [main/WARN] [mixin/]: Error loading class: sereneseasons/season/RandomUpdateHandler (java.lang.ClassNotFoundException: sereneseasons.season.RandomUpdateHandler)
# [17:42:32] [main/WARN] [mixin/]: @Mixin target sereneseasons.season.RandomUpdateHandler was not found snowrealmagic.mixins.json:sereneseasons.RandomUpdateHandlerMixin
# 8playit (v0.15.26): 1744220552635 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue ItemStackCreationStatistics from mod jei as it's dev only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.travelersbackpack.UntrackedIssue002 will NOT be loaded as mod travelersbackpack is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.travelersbackpack.UntrackedIssue001 will NOT be loaded as mod travelersbackpack is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.toolbelt.UntrackedIssue001 will NOT be loaded as mod toolbelt is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.tfcthermaldeposits.UntrackedIssue001 will NOT be loaded as mod tfcthermaldeposits is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.smallships.UntrackedIssue001 will NOT be loaded as mod smallships is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.sereneseasons.UntrackedIssue001 will NOT be loaded as mod sereneseasons is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.railcraft.UntrackedIssue001 will NOT be loaded as mod railcraft is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.pneumaticcraft.UntrackedIssue001 will NOT be loaded as mod pneumaticcraft is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.phosphophyllite.UntrackedIssue001 will NOT be loaded as mod phosphophyllite is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.occultism.UntrackedIssue001 will NOT be loaded as mod occultism is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.moonlight.UntrackedIssue001 will be loaded as it matches versions: 1.20-2.13.81 in [1.20-2.13.32,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to allowed list: [main.FakeLevelManagerMixin]
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.minecraft.UntrackedIssue002 will be loaded as it matches versions: 1.20.1 in 1.20.1
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to allowed list: [main.EntityTickListMixin]
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.minecraft.UntrackedIssue001 will be loaded as it matches versions: 1.20.1 in 1.20.1
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.irons_spellbooks.UntrackedIssue001 will NOT be loaded as mod irons_spellbooks is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.forge.UntrackedIssue003 will be loaded as it matches versions: 47.4.0 in [47.2,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.forge.UntrackedIssue002 will be loaded as it matches versions: 47.4.0 in [47.2,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to allowed list: [accessor.FakePlayerNetHandlerAccessor, accessor.ConnectionAccessor]
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.forge.UntrackedIssue001 will be loaded as it matches versions: 47.4.0 in [47.2,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to allowed list: [main.ServerPlayerMixin, main.PlayerListMixin]
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.forbidden_arcanus.UntrackedIssue001 will NOT be loaded as mod forbidden_arcanus is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.domesticationinnovation.UntrackedIssue001 will NOT be loaded as mod domesticationinnovation is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.curios.UntrackedIssue001 will be loaded as it matches versions: 5.12.1+1.20.1 in [5.9.1,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to allowed list: [main.CuriosEventHandlerMixin]
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.createaddition.UntrackedIssue001 will NOT be loaded as mod createaddition is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.create.UntrackedIssue001 will NOT be loaded as mod create is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.citadel.UntrackedIssue001 will be loaded as it matches versions: 2.6.1 in [2.5.4,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.betterf3.UntrackedIssue001 will NOT be loaded as mod betterf3 is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.badpackets.UntrackedIssue001 will NOT be loaded as mod badpackets is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.ars_nouveau.UntrackedIssue002 will NOT be loaded as mod ars_nouveau is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.ars_nouveau.UntrackedIssue001 will NOT be loaded as mod ars_nouveau is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.architectury.UntrackedIssue001 will be loaded as it matches versions: 9.2.14 in [9.0.8,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.alexsmobs.Issue2165 will be loaded as it matches versions: 1.22.9 in [1.22.5,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.aether.UntrackedIssue001 will NOT be loaded as mod aether is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.leaks.common.mods.ae2wtlib.UntrackedIssue001 will NOT be loaded as mod ae2wtlib is not present
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod twilightforest as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod travelersbackpack as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod tombstone as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod sereneseasons as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod pneumaticcraft as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod nuclearcraft as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod mowziesmobs as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod mowziesmobs as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod mousetweaks as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod mna as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod minecraft as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod minecraft as mod modernfix is present!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod minecolonies as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod minecolonies as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod ldlib as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod journeymap as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod jeresources as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod jei as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod jei as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod irons_spellbooks as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod irons_spellbooks as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod iceberg as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod iceberg as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod iceberg as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod geckolib as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod ftblibrary as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod flywheel as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod findme as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod entity_texture_features as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod entity_model_features as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod emi_loot as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod emi as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod easy_villagers as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod difficultylock as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod cyclopscore as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod corpse as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod citadel as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod blue_skies as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod beansbackpacks as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod badpackets as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod ae2wtlib as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping issue [untracked] from mod ae2wtlib as it is client side only!
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Class dev.uncandango.alltheleaks.fix.common.mods.modernfix.CancelRLMixin will be loaded as it matches versions: 5.20.2+mc1.20.1 in [5.0.0,)
# [17:42:33] [main/INFO] [de.un.al.AllTheLeaks/]: Mixins added to cancel list: [org.embeddedt.modernfix.common.mixin.perf.deduplicate_location.MixinResourceLocation]
# [17:42:34] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping feature ResourceLocation Deduplication from mod minecraft as it's feature flag is not activated!
# [17:42:34] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping feature Ingredient Deduplication from mod minecraft as it's feature flag is not activated!
# [17:42:34] [main/INFO] [de.un.al.AllTheLeaks/]: Skipping feature Prevent Search Ignored Items from mod jei as it's feature flag is not activated!
# [17:42:34] [main/WARN] [mixin/]: Error loading class: com/simibubi/create/content/fluids/spout/FillingBySpout (java.lang.ClassNotFoundException: com.simibubi.create.content.fluids.spout.FillingBySpout)
# [17:42:34] [main/WARN] [mixin/]: Error loading class: vazkii/quark/addons/oddities/inventory/BackpackMenu (java.lang.ClassNotFoundException: vazkii.quark.addons.oddities.inventory.BackpackMenu)
# [17:42:34] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/inventory/CraftingScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.inventory.CraftingScreen)
# [17:42:34] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.inventory.CraftingScreen was not found fastbench.mixins.json:MixinCraftingScreen
# [17:42:34] [main/WARN] [mixin/]: Error loading class: dev/ftb/mods/ftbchunks/data/ClaimedChunkManagerImpl (java.lang.ClassNotFoundException: dev.ftb.mods.ftbchunks.data.ClaimedChunkManagerImpl)
# [17:42:34] [main/WARN] [mixin/]: @Mixin target dev.ftb.mods.ftbchunks.data.ClaimedChunkManagerImpl was not found doespotatotick.mixins.json:ClaimedChunkManagerAccessor
# [17:42:35] [main/INFO] [co.te.re.Redirector/]: Redirecting com/bawnorton/mixinsquared/adjuster/tools/AdjustableAnnotationNode$KnownAnnotations
# [17:42:35] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.4.1).
# [17:42:35] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/util/Unit
# [17:42:35] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/ChatFormatting
# 8playit (v0.15.26): 1744220555726 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:36] [main/INFO] [minecraft/Bootstrap]: ModernFix reached bootstrap stage (1.542 min after launch)
# [17:42:38] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/Util$IdentityStrategy
# [17:42:38] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Holder$Reference$Type
# [17:42:38] [main/WARN] [mixin/]: @Final field delegatesByName:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [17:42:38] [main/WARN] [mixin/]: @Final field delegatesByValue:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [17:42:38] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:38] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:38] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into getOpacityIfCached from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [17:42:38] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into isConditionallyFullOpaque from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# 8playit (v0.15.26): 1744220558991 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:39] [main/WARN] [mixin/]: @Inject(@At("INVOKE")) Shift.BY=1 on crittersandcompanions.mixins.json:LivingEntityMixin::handler$bnb000$onDie exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [17:42:41] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Direction
# [17:42:41] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Direction$AxisDirection
# [17:42:41] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Direction$Axis
# 8playit (v0.15.26): 1744220562082 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Direction$Plane
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/FrontAndTop
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/AttachFace
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/BellAttachType
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/WallSide
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/RedstoneSide
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/DoubleBlockHalf
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/Half
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/RailShape
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/BedPart
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/ChestType
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/ComparatorMode
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/DoorHingeSide
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/NoteBlockInstrument
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/NoteBlockInstrument$Type
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/PistonType
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/SlabType
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/StairsShape
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/StructureMode
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/BambooLeaves
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/Tilt
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/DripstoneThickness
# [17:42:43] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/properties/SculkSensorPhase
# 8playit (v0.15.26): 1744220565189 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:45] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/material/PushReaction
# [17:42:46] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/state/BlockBehaviour$OffsetType
# [17:42:46] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/pathfinder/PathComputationType
# [17:42:46] [main/INFO] [minecraft/Bootstrap]: Vanilla bootstrap took 9474 milliseconds
# [17:42:47] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/network/NetworkDirection
# [17:42:47] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/DyeColor
# [17:42:47] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/util/ByIdMap$OutOfBoundsStrategy
# [17:42:47] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/effect/MobEffectCategory
# [17:42:47] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/ai/attributes/AttributeModifier$Operation
# [17:42:48] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:48] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/PressurePlateBlock$Sensitivity
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/MultifaceSpreader$SpreadType
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/InteractionHand
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/InteractionResult
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/biome/Biome$Precipitation
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/amendments/reg/ModBlockProperties$SignAttachment
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/amendments/reg/ModBlockProperties$BlockAttachment
# [17:42:48] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/SkullBlock$Types
# [17:42:49] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/WeatheringCopper$WeatherState
# [17:42:50] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/Rarity
# [17:42:50] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/vehicle/AbstractMinecart$Type
# [17:42:50] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/MobCategory
# 8playit (v0.15.26): 1744220570605 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:51] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/ai/goal/Goal$Flag
# [17:42:52] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/Pose
# [17:42:52] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/animal/sniffer/Sniffer$State
# [17:42:52] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/EquipmentSlot
# [17:42:52] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/EquipmentSlot$Type
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/ArmorItem$Type
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/vehicle/Boat$Type
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/ArmorMaterials
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/Tiers
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/network/protocol/game/ClientboundPlayerInfoUpdatePacket$Action
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/enchantment/Enchantment$Rarity
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/enchantment/ProtectionEnchantment$Type
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/enchantment/EnchantmentCategory
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/scores/criteria/ObjectiveCriteria$RenderType
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/Heightmap$Types
# 8playit (v0.15.26): 1744220573758 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:53] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/Heightmap$Usage
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/chunk/ChunkStatus$ChunkType
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/crafting/CraftingBookCategory
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/crafting/CookingBookCategory
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/core/Holder$Kind
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/placement/CaveSurface
# [17:42:54] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/placement/StructurePlacement$FrequencyReductionMethod
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/placement/RandomSpreadType
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/StructureSpawnOverride$BoundingBoxType
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/GenerationStep$Decoration
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/TerrainAdjustment
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/structures/MineshaftStructure$Type
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/structures/OceanRuinStructure$Type
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/structures/RuinedPortalPiece$VerticalPlacement
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/GenerationStep$Carving
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/biome/Biome$TemperatureModifier
# [17:42:55] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/biome/BiomeSpecialEffects$GrassColorModifier
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/SurfaceRules$Temperature
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/SurfaceRules$Steep
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/SurfaceRules$Hole
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/SurfaceRules$AbovePreliminarySurface
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/SurfaceRules$Bandlands
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$BlendAlpha
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$BlendOffset
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$BeardifierMarker
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$Marker$Type
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$WeirdScaledSampler$RarityValueMapper
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$Mapped$Type
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/DensityFunctions$TwoArgumentSimpleFunction$Type
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/levelgen/structure/pools/StructureTemplatePool$Projection
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/CreativeModeTab$Row
# [17:42:56] [main/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/item/CreativeModeTab$Type
# 8playit (v0.15.26): 1744220576842 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/config/ChopCountingAlgorithm
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/config/Rounder
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/config/ListType
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/settings/SettingsField
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/settings/SneakBehavior
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting ht/treechop/common/platform/ModLoader
# [17:42:57] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting fuzs/puzzleslib/api/core/v1/ContentRegistrationFlags
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting fuzs/easyanvils/config/ServerConfig$PriorWorkPenalty
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting fuzs/easyanvils/config/ServerConfig$FreeRenames
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting fuzs/easyanvils/config/ServerConfig$RenameAndRepairCost
# [17:42:58] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for easyanvils:main
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/event/TickEvent$Phase
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/event/TickEvent$Type
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/server/packs/PackType
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting fuzs/puzzleslib/api/network/v2/MessageDirection
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting com/starfish_studios/naturalist/common/entity/Butterfly$Variant
# [17:42:58] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting com/starfish_studios/naturalist/common/entity/Snail$Color
# [17:42:59] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedcore/client/gui/SortButtonsPosition
# [17:42:59] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/common/world/BiomeModifier$Phase
# [17:42:59] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/commands/Commands$CommandSelection
# [17:42:59] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/blay09/mods/balm/api/event/TickPhase
# [17:42:59] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/blay09/mods/balm/api/event/EventPriority
# [17:43:00] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/blay09/mods/kleeslabs/KleeSlabsMode
# [17:43:00] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/ClipContext$Fluid
# [17:43:00] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/entity/MobSpawnType
# [17:43:01] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/world/level/block/Rotation
# [17:43:01] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting com/mojang/math/OctahedralGroup
# [17:43:01] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting com/mojang/math/SymmetricGroup3
# 8playit (v0.15.26): 1744220581361 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [17:43:01] [modloading-worker-0/INFO] [MaxHealthFix/]: Loaded maxhealthfix for Forge.
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/darkhax/bookshelf/api/PhysicalSide
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/darkhax/bookshelf/api/event/IEventHelper$Ordering
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedcore/upgrades/jukebox/RepeatMode
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/blay09/mods/balm/config/ExampleConfigData$ExampleEnum
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/common/capabilities/CapabilityManager
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting tschipp/carryon/config/PropertyType
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedcore/upgrades/feeding/HungerLevel
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedbackpacks/upgrades/refill/RefillUpgradeWrapper$TargetSlot
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedbackpacks/upgrades/inception/InventoryOrder
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedbackpacks/upgrades/toolswapper/ToolSwapMode
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/p3pp3rf1y/sophisticatedcore/upgrades/xppump/AutomationDirection
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraftforge/event/entity/player/PlayerInteractEvent$LeftClickBlock$Action
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting tictim/paraglider/api/plugin/ConflictResolver$Resolution
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting tictim/paraglider/impl/movement/PlayerStateMapLoader$State$CheckStatus
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting tictim/paraglider/forge/contents/ConfigConditionSerializer
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting tictim/paraglider/config/Cfg$TotwCompatConfigOption
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/moonlight/api/platform/RegHelper$VariantType
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/moonlight/api/platform/PlatHelper$Side
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/moonlight/api/platform/network/NetworkDir
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/sawmill/CommonConfigs$SearchMode
# [17:43:02] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/moonlight/api/platform/configs/ConfigType
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/minecraft/server/packs/repository/Pack$Position
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/configs/CommonConfigs$ReplaceTableMode
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/moonlight/api/platform/PlatHelper$Platform
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/common/block/blocks/BlackboardBlock$UseMode
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/configs/CommonConfigs$Hands
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/common/entities/BombEntity$BreakingMode
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/configs/CommonConfigs$DeathMarkerMode
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting net/mehvahdjukaar/supplementaries/configs/CommonConfigs$SlimedJumpMode
# [17:43:03] [modloading-worker-0/INFO] [co.te.re.Redirector/]: Redirecting toni/sodiumdynamiclights/DynamicLightsMode
# ...
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [18:05:49] [Server thread/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.ZombieVillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# >....8playit (v0.15.26): 1744221952995 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221956644 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221959763 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221962850 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221966094 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221969567 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221972978 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221976249 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221979713 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221982799 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221986082 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221989334 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221992510 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221996298 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744221999498 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222002642 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222005752 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222008882 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222011974 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222015715 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222018981 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222022623 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222025718 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222029016 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222032166 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222035291 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222038422 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222041572 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222044741 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222047836 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222051226 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222054526 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222057673 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222060774 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222064569 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222067698 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222070825 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222074103 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222077338 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222080427 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222083517 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222086671 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222090277 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222093404 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222096611 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222100253 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222103511 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222106760 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222109859 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222112983 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222116427 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222119739 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222124069 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222127420 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222130593 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222133722 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222136972 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222140549 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222143634 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222146726 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222149968 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222153081 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222156274 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222159355 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# [18:09:21] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: juanlu_serra lost connection: Disconnected
# [18:09:21] [Server thread/INFO] [minecraft/MinecraftServer]: juanlu_serra left the game
# >....8playit (v0.15.26): 1744222162453 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222165730 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)
# 8playit (v0.15.26): 1744222168839 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# fast-es.gl.joinmc.link => 127.0.0.1:25565 (minecraft-java)

# %% [markdown]
# **FAQ - COSAS QUE TIENES QUE SABER**
#
# Google Colab no esta pensado para crear servidores de Minecraft, pero se pueden hacer. Google Colab promete funcionar 12 horas seguidas, sin embargo es posible que se cierre si no hay una persona que este revisando la página o usando la consola, basicamente si la página detecta inactividad el proceso terminará. El rendimiento es de 12 GB de RAM aproximadamente, junto con un procesador con una potencia de 2.2 GHz y 2 theards, esto es mejor que muchos hostings de pago, pero no tiene soporte y no promete estar abierto siempre, se pueden poner mods, pero no es recomendable saturarlo con muchos al igual que plugins, lo que más limita a este servidor es su procesador el cuál, no es muy bueno, cualquier hosting por 12 USD puede ofrecerte un servidor de mayor calidad, si tienes pensado crear algo para muchos usuarios, es mucho mejor eso. Los servidores utilizados son los de Google junto con el proxy de Ngrok.
